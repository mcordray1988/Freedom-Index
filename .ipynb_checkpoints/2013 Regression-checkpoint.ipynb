# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
index = pd.read_csv('data/basic_index/index_full.csv')
del index['Unnamed: 0']

# %%
# Creating a dict of dataframes, separated by Index Year
# This can easily be changed to seperate by Country instead if desired
unique_country = index['Index Year'].unique()

country_dict_df = {elem : pd.DataFrame() for elem in unique_country}
country_dict_df

for key in country_dict_df.keys():
    country_dict_df[key] = index[:][index['Index Year'] == key]

# %%
freedom_data = country_dict_df[2013]
diversity_data = pd.read_csv("data/HIEF_data.csv")

# %%
freedom_data = freedom_data.drop(freedom_data.columns[[5,8]], axis=1)

# %%
freedom_data.count()
# Out:
# Name                    185
# Index Year              185
# Overall Score           185
# Property Rights         185
# Government Integrity    185
# Tax Burden              185
# Government Spending     185
# Business Freedom        185
# Labor Freedom           185
# Monetary Freedom        185
# Trade Freedom           185
# Investment Freedom      185
# Financial Freedom       185
# dtype: int64

# %%
freedom_data = freedom_data.dropna()
freedom_data[0:40]
# Out:
#                           Name  Index Year  Overall Score  Property Rights  \
# 1833               Afghanistan        2013          59.65            42.97
# 1834                   Albania        2013          65.20            30.00
# 1835                   Algeria        2013          49.60            30.00
# 1836                    Angola        2013          47.30            15.00
# 1837                 Argentina        2013          46.70            15.00
# 1838                   Armenia        2013          69.40            30.00
# 1839                 Australia        2013          82.60            90.00
# 1840                   Austria        2013          71.80            90.00
# 1841                Azerbaijan        2013          59.70            25.00
# 1842                   Bahrain        2013          75.50            55.00
# 1843               Bangladesh         2013          52.60            20.00
# 1844                  Barbados        2013          69.30            80.00
# 1845                   Belarus        2013          48.00            20.00
# 1846                   Belgium        2013          69.20            80.00
# 1847                    Belize        2013          57.30            30.00
# 1848                     Benin        2013          57.60            30.00
# 1849                    Bhutan        2013          55.00            60.00
# 1850                   Bolivia        2013          47.90            10.00
# 1851    Bosnia and Herzegovina        2013          57.30            20.00
# 1852                  Botswana        2013          70.60            70.00
# 1853                    Brazil        2013          57.70            50.00
# 1854                  Bulgaria        2013          65.00            30.00
# 1855              Burkina Faso        2013          59.90            30.00
# 1856                     Burma        2013          39.20            10.00
# 1857                   Burundi        2013          49.00            20.00
# 1858                Cabo Verde        2013          63.70            70.00
# 1859                  Cambodia        2013          58.50            30.00
# 1860                  Cameroon        2013          52.30            30.00
# 1861                    Canada        2013          79.40            90.00
# 1862  Central African Republic        2013          50.40            20.00
# 1863                      Chad        2013          45.20            20.00
# 1864                     Chile        2013          79.00            90.00
# 1865                     China        2013          51.90            20.00
# 1866                  Colombia        2013          69.60            50.00
# 1867                   Comoros        2013          47.50            30.00
# 1868               Costa Rica         2013          67.00            50.00
# 1869            Côte d'Ivoire         2013          54.10            25.00
# 1870                   Croatia        2013          61.30            40.00
# 1871                      Cuba        2013          28.50            10.00
# 1872                    Cyprus        2013          69.00            70.00
#
#       Government Integrity  Tax Burden  Government Spending  Business Freedom  \
# 1833                  15.0       77.38                 83.2              59.7
# 1834                  31.0       92.60                 75.1              81.0
# 1835                  29.0       80.40                 44.1              65.2
# 1836                  20.0       82.60                 60.6              43.1
# 1837                  30.0       64.30                 52.1              60.1
# 1865           62.6              71.6           72.0                25.0
# 1866           79.3              78.7           72.2                70.0
# 1867           51.2              74.6           68.8                15.0
# 1868           60.4              75.4           85.1                70.0
# 1869           54.6              77.8           70.3                40.0
# 1870           42.4              81.1           87.5                75.0
# 1871           20.0              67.4           62.7                 0.0
# 1872           62.8              84.1           81.8                75.0
#
#       Financial Freedom
# 1833              48.61
# 1834              70.00
# 1835              30.00
# 1836              40.00
# 1837              30.00
# 1838              70.00
# 1839              90.00
# 1840              70.00
# 1841              40.00
# 1842              80.00
# 1843              20.00
# 1844              60.00
# 1845              10.00
# 1846              70.00
# 1847              50.00
# 1848              50.00
# 1849              30.00
# 1850              50.00
# 1851              60.00
# 1852              70.00
# 1853              60.00
# 1854              60.00
# 1855              50.00
# 1856              10.00
# 1857              30.00
# 1858              60.00
# 1859              50.00
# 1860              50.00
# 1861              80.00
# 1862              30.00
# 1863              40.00
# 1864              70.00
# 1865              30.00
# 1866              70.00
# 1867              20.00
# 1868              50.00
# 1869              50.00
# 1870              60.00
# 1871              10.00
# 1872              60.00

# %%
diversity_data
# Out:
#              Country  Year  EFindex
# 0     United Kingdom  1945    0.309
# 1     United Kingdom  1946    0.309
# 2     United Kingdom  1947    0.309
# 3     United Kingdom  1948    0.309
# 4     United Kingdom  1949    0.309
# ...              ...   ...      ...
# 8803            Fiji  2009    0.534
# 8804            Fiji  2010    0.533
# 8805            Fiji  2011    0.531
# 8806            Fiji  2012    0.529
# 8807            Fiji  2013    0.528
#
# [8808 rows x 3 columns]

# %%
diversity_data = diversity_data[diversity_data['Year'] == 2013]
diversity_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 156 entries, 68 to 8807
# Data columns (total 3 columns):
# Country    156 non-null object
# Year       156 non-null int64
# EFindex    156 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.9+ KB

# %%
merged_data = freedom_data.merge(diversity_data, how="left", left_on="Name", right_on = "Country")

# %%
merged_data = merged_data.dropna(subset=["EFindex"])

# %%
from sklearn.linear_model import LinearRegression
X = merged_data["Overall Score"].values.reshape(-1,1)
y = merged_data["EFindex"].tolist()
model = LinearRegression()
y
# Out:
# [0.763,
#  0.139,
#  0.37200000000000005,
#  0.779,
#  0.158,
#  0.045,
#  0.276,
#  0.248,
#  0.122,
#  0.5820000000000001,
#  0.309,
#  0.5920000000000001,
#  0.764,
#  0.6509999999999999,
#  0.5720000000000001,
#  0.395,
#  0.5589999999999999,
#  0.289,
#  0.767,
#  0.308,
#  0.158,
#  0.73,
#  0.79,
#  0.855,
#  0.439,
#  0.19,
#  0.639,
#  0.054000000000000006,
#  0.171,
#  0.517,
#  0.34700000000000003,
#  0.262,
#  0.7,
#  0.177,
#  0.649,
#  0.45299999999999996,
#  0.528,
#  0.040999999999999995,
#  0.659,
#  0.45799999999999996,
#  0.7829999999999999,
#  0.528,
#  0.138,
#  0.789,
#  0.36700000000000005,
#  0.736,
#  0.16699999999999998,
#  0.727,
#  0.8079999999999999,
#  0.695,
#  0.105,
#  0.8029999999999999,
#  0.743,
#  0.446,
#  0.174,
#  0.376,
#  0.11,
#  0.019,
#  0.044000000000000004,
#  0.5379999999999999,
#  0.855,
#  0.765,
#  0.634,
#  0.547,
#  0.133,
#  0.313,
#  0.889,
#  0.259,
#  0.284,
#  0.562,
#  0.19399999999999998,
#  0.7909999999999999,
#  0.852,
#  0.713,
#  0.466,
#  0.5870000000000001,
#  0.42700000000000005,
#  0.315,
#  0.5660000000000001,
#  0.76,
#  0.86,
#  0.354,
#  0.485,
#  0.6659999999999999,
#  0.85,
#  0.151,
#  0.597,
#  0.618,
#  0.807,
#  0.069,
#  0.22,
#  0.708,
#  0.207,
#  0.376,
#  0.28,
#  0.22399999999999998,
#  0.747,
#  0.8009999999999999,
#  0.395,
#  0.24100000000000002,
#  0.258,
#  0.09699999999999999,
#  0.222,
#  0.856,
#  0.669,
#  0.32299999999999995,
#  0.746,
#  0.21899999999999997,
#  0.36700000000000005,
#  0.213,
#  0.373,
#  0.36700000000000005,
#  0.591,
#  0.88,
#  0.655,
#  0.034,
#  0.521,
#  0.255,
#  0.883,
#  0.37,
#  0.684,
#  0.39899999999999997,
#  0.313,
#  0.706,
#  0.415]

# %%
model.fit(X, y)
print(model)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model = LinearRegression(normalize=True)
model.fit(X,y)
score = model.score(X,y)
print(f'R^2 Score: {score}')
# Out:
# R^2 Score: 0.04989470881218405

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [-0.0051868]
# y-axis intercept:  0.7805430854448854

# %%
predictions = model.predict(X)
print(f"True output: {y[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y[0]}")
# Out:
# True output: 0.763
# Predicted output: 0.47115039432419636
# Prediction Error: -0.29184960567580365

# %%
pd.DataFrame({"Predicted": predictions, "Actual": y, "Error": predictions - y})[["Predicted", "Actual", "Error"]]
# Out:
#      Predicted  Actual     Error
# 0     0.471150   0.763 -0.291850
# 1     0.442364   0.139  0.303364
# 2     0.523278   0.372  0.151278
# 3     0.535207   0.779 -0.243793
# 4     0.538319   0.158  0.380319
# ..         ...     ...       ...
# 120   0.411762   0.684 -0.272238
# 121   0.392570   0.399 -0.006430
# 122   0.541950   0.313  0.228950
# 123   0.476078   0.706 -0.229922
# 124   0.632201   0.415  0.217201
#
# [125 rows x 3 columns]

# %%
y = merged_data["EFindex"].values.reshape(-1,1)
x_min = X.min()
x_max = X.max()
y_min_actual = y.min()
y_max_actual = y.max()

# %%
y_min_predicted = model.predict([[x_min]])
y_max_predicted = model.predict([[x_max]])
print(f"Actual Min Value: {y_min_actual}")
print(f"Predicted Min Value: {y_min_predicted}")
print(f"Actual Max Value: {y_max_actual}")
print(f"Predicted Max Value: {y_max_predicted}")
# Out:
# Actual Min Value: 0.019
# Predicted Min Value: [0.63271925]
# Actual Max Value: 0.889
# Predicted Max Value: [0.32410458]

# %%
plt.figure(figsize=(12,8))
plt.scatter(X, y, c='blue')
plt.plot([x_min, x_max], [y_min_actual, y_max_actual], c='red')
plt.xlabel("2013 Index of Economic Freedom Score")
plt.ylabel("2013 Diversity Index")
plt.title("Single-Variable Regression of 2013 IEF Score vs. Diversity Score")
plt.show()
plt.savefig("/images/Regression2013.png")
