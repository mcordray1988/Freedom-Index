# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
bottom_five_ethnicity = pd.read_csv('../final-project/data/bottom_5_HIEF_data.csv')
bottom_five_ethnicity
# Out:
#        Country  Year  EFindex
# 0        Congo  1960    0.700
# 1        Congo  1961    0.701
# 2        Congo  1962    0.701
# 3        Congo  1963    0.702
# 4        Congo  1964    0.702
# ..         ...   ...      ...
# 257  Venezuela  2009    0.516
# 258  Venezuela  2010    0.517
# 259  Venezuela  2011    0.518
# 260  Venezuela  2012    0.519
# 261  Venezuela  2013    0.520
#
# [262 rows x 3 columns]

# %%
congo = bottom_five_ethnicity[(bottom_five_ethnicity.Country == 'Congo')]
congo
# Out:
#    Country  Year  EFindex
# 0    Congo  1960    0.700
# 1    Congo  1961    0.701
# 2    Congo  1962    0.701
# 3    Congo  1963    0.702
# 4    Congo  1964    0.702
# 5    Congo  1965    0.702
# 6    Congo  1966    0.703
# 7    Congo  1967    0.703
# 8    Congo  1968    0.703
# 9    Congo  1969    0.704
# 10   Congo  1970    0.704
# 11   Congo  1971    0.704
# 12   Congo  1972    0.705
# 13   Congo  1973    0.705
# 14   Congo  1974    0.705
# 15   Congo  1975    0.705
# 16   Congo  1976    0.705
# 17   Congo  1977    0.706
# 18   Congo  1978    0.706
# 19   Congo  1979    0.706
# 20   Congo  1980    0.706
# 21   Congo  1981    0.706
# 22   Congo  1982    0.707
# 23   Congo  1983    0.707
# 24   Congo  1984    0.707
# 25   Congo  1985    0.707
# 26   Congo  1986    0.707
# 27   Congo  1987    0.707
# 28   Congo  1988    0.707
# 29   Congo  1989    0.707
# 30   Congo  1990    0.707
# 31   Congo  1991    0.707
# 32   Congo  1992    0.707
# 33   Congo  1993    0.707
# ...

# %%
X = congo.Year.values.reshape(-1, 1)
y = congo.EFindex.values.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X, y)
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[1960]]
# Max X Value: [[2013]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.figure(figsize=(15,10))
plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.title("Congo")
plt.xlabel("Years")
plt.ylabel("EF Index")
# Out:
# Text(0, 0.5, 'EF Index')

# %%
cuba = bottom_five_ethnicity[(bottom_five_ethnicity.Country == 'Cuba')]
cuba
# Out:
#     Country  Year  EFindex
# 124    Cuba  1945    0.448
# 125    Cuba  1946    0.448
# 126    Cuba  1947    0.448
# 127    Cuba  1948    0.448
# 128    Cuba  1949    0.448
# ..      ...   ...      ...
# 188    Cuba  2009    0.511
# 189    Cuba  2010    0.513
# 190    Cuba  2011    0.514
# 191    Cuba  2012    0.516
# 192    Cuba  2013    0.517
#
# [69 rows x 3 columns]

# %%
X = cuba.Year.values.reshape(-1, 1)
y = cuba.EFindex.values.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X, y)
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[1945]]
# Max X Value: [[2013]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.figure(figsize=(15,10))
plt.scatter(X, y, c='green')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.title("Cuba")
plt.xlabel("Years")
plt.ylabel("EF Index")
# Out:
# Text(0, 0.5, 'EF Index')

# %%
eritrea = bottom_five_ethnicity[(bottom_five_ethnicity.Country == 'Eritrea')]
eritrea
# Out:
#     Country  Year  EFindex
# 54  Eritrea  1993    0.674
# 55  Eritrea  1994    0.675
# 56  Eritrea  1995    0.675
# 57  Eritrea  1996    0.675
# 58  Eritrea  1997    0.675
# 59  Eritrea  1998    0.675
# 60  Eritrea  1999    0.675
# 61  Eritrea  2000    0.675
# 62  Eritrea  2001    0.674
# 63  Eritrea  2002    0.674
# 64  Eritrea  2003    0.673
# 65  Eritrea  2004    0.673
# 66  Eritrea  2005    0.672
# 67  Eritrea  2006    0.671
# 68  Eritrea  2007    0.669
# 69  Eritrea  2008    0.668
# 70  Eritrea  2009    0.667
# 71  Eritrea  2010    0.665
# 72  Eritrea  2011    0.663
# 73  Eritrea  2012    0.661
# 74  Eritrea  2013    0.659

# %%
X = eritrea.Year.values.reshape(-1, 1)
y = eritrea.EFindex.values.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X, y)
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[1993]]
# Max X Value: [[2013]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.figure(figsize=(15,10))
plt.scatter(X, y, c='black')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.title("Eritrea")
plt.xlabel("Years")
plt.ylabel("EF Index")
# Out:
# Text(0, 0.5, 'EF Index')

# %%
zimbabwe = bottom_five_ethnicity[(bottom_five_ethnicity.Country == 'Zimbabwe')]
zimbabwe
# Out:
#       Country  Year  EFindex
# 75   Zimbabwe  1965    0.385
# 76   Zimbabwe  1966    0.383
# 77   Zimbabwe  1967    0.381
# 78   Zimbabwe  1968    0.379
# 79   Zimbabwe  1969    0.376
# 80   Zimbabwe  1970    0.374
# 81   Zimbabwe  1971    0.372
# 82   Zimbabwe  1972    0.370
# 83   Zimbabwe  1973    0.368
# 84   Zimbabwe  1974    0.366
# 85   Zimbabwe  1975    0.367
# 86   Zimbabwe  1976    0.369
# 87   Zimbabwe  1977    0.371
# 88   Zimbabwe  1978    0.372
# 89   Zimbabwe  1979    0.374
# 90   Zimbabwe  1980    0.375
# 91   Zimbabwe  1981    0.377
# 92   Zimbabwe  1982    0.378
# 93   Zimbabwe  1983    0.380
# 94   Zimbabwe  1984    0.381
# 95   Zimbabwe  1985    0.383
# 96   Zimbabwe  1986    0.384
# 97   Zimbabwe  1987    0.385
# 98   Zimbabwe  1988    0.387
# 99   Zimbabwe  1989    0.388
# 100  Zimbabwe  1990    0.389
# 101  Zimbabwe  1991    0.391
# 102  Zimbabwe  1992    0.392
# 103  Zimbabwe  1993    0.393
# 104  Zimbabwe  1994    0.395
# 105  Zimbabwe  1995    0.396
# ...

# %%
X = zimbabwe.Year.values.reshape(-1, 1)
y = zimbabwe.EFindex.values.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X, y)
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[1965]]
# Max X Value: [[2013]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.figure(figsize=(15,10))
plt.scatter(X, y, c='teal')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.title("Zimbabwe")
plt.xlabel("Years")
plt.ylabel("EF Index")
# Out:
# Text(0, 0.5, 'EF Index')

# %%
venezuela = bottom_five_ethnicity[(bottom_five_ethnicity.Country == 'Venezuela')]
venezuela
# Out:
#        Country  Year  EFindex
# 193  Venezuela  1945    0.440
# 194  Venezuela  1946    0.441
# 195  Venezuela  1947    0.443
# 196  Venezuela  1948    0.444
# 197  Venezuela  1949    0.445
# ..         ...   ...      ...
# 257  Venezuela  2009    0.516
# 258  Venezuela  2010    0.517
# 259  Venezuela  2011    0.518
# 260  Venezuela  2012    0.519
# 261  Venezuela  2013    0.520
#
# [69 rows x 3 columns]

# %%
X = venezuela.Year.values.reshape(-1, 1)
y = venezuela.EFindex.values.reshape(-1, 1)

# %%
model = LinearRegression()
model.fit(X, y)
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[1945]]
# Max X Value: [[2013]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.figure(figsize=(15,10))
plt.scatter(X, y, c='purple')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.title("Venezuela")
plt.xlabel("Years")
plt.ylabel("EF Index")
# Out:
# Text(0, 0.5, 'EF Index')

# %%
data = (congo, cuba, eritrea, zimbabwe, venezuela)
colors = ("blue", "green", "black", "teal", "purple")
groups = ("Congo", "Cuba", "Eritrea", "Zimbabwe", "Venezuela")

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(1,1,1)

for data, color, group in zip(data, colors, groups):
  
    x = bottom_five_ethnicity.Year.values.reshape(-1, 1)
    y = bottom_five_ethnicity.EFindex.values.reshape(-1, 1)
    
    ax.scatter(x, y, alpha=0.8, c=color, edgecolor='none', s=30, label=group)
  
plt.title('Group Plot')
plt.legend(loc=2)
plt.show()
